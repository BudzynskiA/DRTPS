# %%
#Import needed library.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('DRTPS.csv',delimiter=',',header='infer')

# %%
# Create new features

# Classification country load place:
df['LC_AD'] = df['LC'] == 'AD'
df['LC_AL'] = df['LC'] == 'AL'
df['LC_AM'] = df['LC'] == 'AM'
df['LC_AT'] = df['LC'] == 'AT'
df['LC_AZ'] = df['LC'] == 'AZ'
df['LC_BA'] = df['LC'] == 'BA'
df['LC_BE'] = df['LC'] == 'BE'
df['LC_BG'] = df['LC'] == 'BG'
df['LC_BY'] = df['LC'] == 'BY'
df['LC_CH'] = df['LC'] == 'CH'
df['LC_CY'] = df['LC'] == 'CY'
df['LC_CZ'] = df['LC'] == 'CZ'
df['LC_DE'] = df['LC'] == 'DE'
df['LC_DK'] = df['LC'] == 'DK'
df['LC_EE'] = df['LC'] == 'EE'
df['LC_ES'] = df['LC'] == 'ES'
df['LC_FI'] = df['LC'] == 'FI'
df['LC_FR'] = df['LC'] == 'FR'
df['LC_GB'] = df['LC'] == 'GB'
df['LC_GE'] = df['LC'] == 'GE'
df['LC_GR'] = df['LC'] == 'GR'
df['LC_HR'] = df['LC'] == 'HR'
df['LC_HU'] = df['LC'] == 'HU'
df['LC_IE'] = df['LC'] == 'IE'
df['LC_IS'] = df['LC'] == 'IS'
df['LC_IT'] = df['LC'] == 'IT'
df['LC_KZ'] = df['LC'] == 'KZ'
df['LC_LT'] = df['LC'] == 'LT'
df['LC_LU'] = df['LC'] == 'LU'
df['LC_LV'] = df['LC'] == 'LV'
df['LC_MD'] = df['LC'] == 'MD'
df['LC_ME'] = df['LC'] == 'ME'
df['LC_MK'] = df['LC'] == 'MK'
df['LC_NL'] = df['LC'] == 'NL'
df['LC_NO'] = df['LC'] == 'NO'
df['LC_PL'] = df['LC'] == 'PL'
df['LC_PT'] = df['LC'] == 'PT'
df['LC_RO'] = df['LC'] == 'RO'
df['LC_RS'] = df['LC'] == 'RS'
df['LC_RU'] = df['LC'] == 'RU'
df['LC_SE'] = df['LC'] == 'SE'
df['LC_SI'] = df['LC'] == 'SI'
df['LC_SK'] = df['LC'] == 'SK'
df['LC_TR'] = df['LC'] == 'TR'
df['LC_UA'] = df['LC'] == 'UA'

# Classification country delivery place:
df['DC_AD'] = df['DC'] == 'AD'
df['DC_AL'] = df['DC'] == 'AL'
df['DC_AM'] = df['DC'] == 'AM'
df['DC_AT'] = df['DC'] == 'AT'
df['DC_AZ'] = df['DC'] == 'AZ'
df['DC_BA'] = df['DC'] == 'BA'
df['DC_BE'] = df['DC'] == 'BE'
df['DC_BG'] = df['DC'] == 'BG'
df['DC_BY'] = df['DC'] == 'BY'
df['DC_CH'] = df['DC'] == 'CH'
df['DC_CY'] = df['DC'] == 'CY'
df['DC_CZ'] = df['DC'] == 'CZ'
df['DC_DE'] = df['DC'] == 'DE'
df['DC_DK'] = df['DC'] == 'DK'
df['DC_EE'] = df['DC'] == 'EE'
df['DC_ES'] = df['DC'] == 'ES'
df['DC_FI'] = df['DC'] == 'FI'
df['DC_FR'] = df['DC'] == 'FR'
df['DC_GB'] = df['DC'] == 'GB'
df['DC_GE'] = df['DC'] == 'GE'
df['DC_GR'] = df['DC'] == 'GR'
df['DC_HR'] = df['DC'] == 'HR'
df['DC_HU'] = df['DC'] == 'HU'
df['DC_IE'] = df['DC'] == 'IE'
df['DC_IS'] = df['DC'] == 'IS'
df['DC_IT'] = df['DC'] == 'IT'
df['DC_KZ'] = df['DC'] == 'KZ'
df['DC_LT'] = df['DC'] == 'LT'
df['DC_LU'] = df['DC'] == 'LU'
df['DC_LV'] = df['DC'] == 'LV'
df['DC_MD'] = df['DC'] == 'MD'
df['DC_ME'] = df['DC'] == 'ME'
df['DC_MK'] = df['DC'] == 'MK'
df['DC_NL'] = df['DC'] == 'NL'
df['DC_NO'] = df['DC'] == 'NO'
df['DC_PL'] = df['DC'] == 'PL'
df['DC_PT'] = df['DC'] == 'PT'
df['DC_RO'] = df['DC'] == 'RO'
df['DC_RS'] = df['DC'] == 'RS'
df['DC_RU'] = df['DC'] == 'RU'
df['DC_SE'] = df['DC'] == 'SE'
df['DC_SI'] = df['DC'] == 'SI'
df['DC_SK'] = df['DC'] == 'SK'
df['DC_TR'] = df['DC'] == 'TR'
df['DC_UA'] = df['DC'] == 'UA'

#Data as year and month together
df['YM'] = df['Y']+(df['M']/12)

#Month Classification
df['January'] = df['M'] == 1
df['February'] = df['M'] == 2
df['March'] = df['M'] == 3
df['April'] = df['M'] == 4
df['May'] = df['M'] == 5
df['June'] = df['M'] == 6
df['July'] = df['M'] == 7
df['August'] = df['M'] == 8
df['September'] = df['M'] == 9
df['October'] = df['M'] == 10
df['Novemer'] = df['M'] == 11
df['December'] = df['M'] == 12

# %%
#Change false into 0 and true into 1
df = df*1

# %%
X, y = df[[
 'LC_AD',
 'LC_AL',
 'LC_AM',
 'LC_AT',
 'LC_AZ',
 'LC_BA',
 'LC_BE',
 'LC_BG',
 'LC_BY',
 'LC_CH',
 'LC_CY',
 'LC_CZ',
 'LC_DE',
 'LC_DK',
 'LC_EE',
 'LC_ES',
 'LC_FI',
 'LC_FR',
 'LC_GB',
 'LC_GE',
 'LC_GR',
 'LC_HR',
 'LC_HU',
 'LC_IE',
 'LC_IS',
 'LC_IT',
 'LC_KZ',
 'LC_LT',
 'LC_LU',
 'LC_LV',
 'LC_MD',
 'LC_ME',
 'LC_MK',
 'LC_NL',
 'LC_NO',
 'LC_PL',
 'LC_PT',
 'LC_RO',
 'LC_RS',
 'LC_RU',
 'LC_SE',
 'LC_SI',
 'LC_SK',
 'LC_TR',
 'LC_UA',
 'DC_AD',
 'DC_AL',
 'DC_AM',
 'DC_AT',
 'DC_AZ',
 'DC_BA',
 'DC_BE',
 'DC_BG',
 'DC_BY',
 'DC_CH',
 'DC_CY',
 'DC_CZ',
 'DC_DE',
 'DC_DK',
 'DC_EE',
 'DC_ES',
 'DC_FI',
 'DC_FR',
 'DC_GB',
 'DC_GE',
 'DC_GR',
 'DC_HR',
 'DC_HU',
 'DC_IE',
 'DC_IS',
 'DC_IT',
 'DC_KZ',
 'DC_LT',
 'DC_LU',
 'DC_LV',
 'DC_MD',
 'DC_ME',
 'DC_MK',
 'DC_NL',
 'DC_NO',
 'DC_PL',
 'DC_PT',
 'DC_RO',
 'DC_RS',
 'DC_RU',
 'DC_SE',
 'DC_SI',
 'DC_SK',
 'DC_TR',
 'DC_UA',
 'January',
 'February',
 'March',
 'April',
 'May',
 'June',
 'July',
 'August',
 'September',
 'October',
 'Novemer',
 'December',
    'YM'
]].values, df['D'].values

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
# Split data 70%-30% into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

print ('Training Set: %d rows\nTest Set: %d rows' % (X_train.shape[0], X_test.shape[0]))
# Out:
# Training Set: 739 rows
# Test Set: 317 rows

# %%
from sklearn import linear_model

# Train the model
model = linear_model.LinearRegression().fit(X_train, y_train)
print (model, "\n")

# Evaluate the model using the test data
predictions = model.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels')
plt.title('Predicted Demand Transport by LinearRegression model')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
model.score(X_train, y_train)
# Out:
# LinearRegression()
#
# MSE: 212.44852868690853
# RMSE: 14.575614178720173
# R2: 0.5409576940305982
# 0.6736405528983356

# %%
import joblib

# Save the model as a pickle file
filename = 'DRTPS_LinearRegression.pkl'
joblib.dump(model, filename)
# Out:
# ['DRTPS_LinearRegression.pkl']

# %%
from sklearn.linear_model import Ridge

# Train the model
model = linear_model.Ridge().fit(X_train, y_train)
print (model, "\n")

# Evaluate the model using the test data
predictions = model.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels ')
plt.title('Predicted Demand Transport by Ridge model')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
model.score(X_train, y_train)
# Out:
# Ridge()
#
# MSE: 213.20259164188934
# RMSE: 14.601458545018348
# R2: 0.5393283732730483
# 0.6658213771094756

# %%
# Save the model as a pickle file
filename = 'DRTPS_Ridge.pkl'
joblib.dump(model, filename)
# Out:
# ['DRTPS_Ridge.pkl']

# %%
from sklearn.linear_model import RidgeCV

# Train the model
reg = linear_model.RidgeCV
print (reg, "\n")

clf = RidgeCV(alphas=[1e-3, 1e-2, 1e-1, 1]).fit(X_train, y_train)
# Evaluate the model using the test data
predictions = clf.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels ')
plt.title('Predicted Demand Transport by RidgeCV model')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
clf.score(X_train, y_train)
# Out:
# <class 'sklearn.linear_model._ridge.RidgeCV'>
#
# MSE: 213.20259164189093
# RMSE: 14.601458545018403
# R2: 0.539328373273045
# 0.6658213771094768

# %%
# Save the model as a pickle file
filename = 'DRTPS_RidgeCV.pkl'
joblib.dump(clf, filename)
# Out:
# ['DRTPS_RidgeCV.pkl']

# %%
from sklearn import linear_model

# Train the model
clf = linear_model.Lasso(alpha=0.001).fit(X_train, y_train)
print (clf, "\n")
# Evaluate the model using the test data
predictions = clf.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels ')
plt.title('Predicted Demand Transport by Lasso model')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
clf.score(X_train, y_train)
# Out:
# Lasso(alpha=0.001)
#
# MSE: 213.05829872132654
# RMSE: 14.596516663962213
# R2: 0.539640150226269
# 0.6742401025864566

# %%
# Save the model as a pickle file
filename = 'DRTPS_Lasso.pkl'
joblib.dump(clf, filename)
# Out:
# ['DRTPS_Lasso.pkl']

# %%
from sklearn.linear_model import LassoCV
from sklearn.datasets import make_regression

# Train the model
X, y = make_regression(noise=4, random_state=0)
reg = LassoCV(cv=5, random_state=0).fit(X_train, y_train)
print (reg, "\n")

# Evaluate the model using the test data
predictions = reg.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels ')
plt.title('Predicted Demand Transport by LassoCV model')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
reg.score(X_train, y_train)
# Out:
# LassoCV(cv=5, random_state=0)
#
# MSE: 214.8023571250156
# RMSE: 14.656137182935195
# R2: 0.5358717240746593
# 0.6716442665432422

# %%
# Save the model as a pickle file
filename = 'DRTPS_LassoCV.pkl'
joblib.dump(reg, filename)
# Out:
# ['DRTPS_LassoCV.pkl']

# %%
from sklearn import linear_model

# Train the model
reg = linear_model.Lars(n_nonzero_coefs=94).fit(X_train, y_train)

# Evaluate the model using the test data
predictions = reg.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels ')
plt.title('Predicted Demand Transport by Lars model')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
reg.score(X_train, y_train)
# Out:
# MSE: 214.51525067245774
# RMSE: 14.646339155995868
# R2: 0.5364920814330061
# 0.672187527341652

# %%
# Save the model as a pickle file
filename = 'DRTPS_Lars.pkl'
joblib.dump(reg, filename)
# Out:
# ['DRTPS_Lars.pkl']

# %%
from sklearn.linear_model import LarsCV
from sklearn.datasets import make_regression
# Train the model
X, y = make_regression (noise=4, random_state=0,)
reg = LarsCV(cv=3, max_iter=80).fit(X_train, y_train)


# Evaluate the model using the test data
predictions = reg.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels ')
plt.title('Predicted Demand Transport by LarsCV model')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
reg.score(X_train, y_train)
# Out:
# MSE: 220.75609041334036
# RMSE: 14.85786291541756
# R2: 0.5230073588813983
# 0.656255474751464

# %%
# Save the model as a pickle file
filename = 'DRTPS_LarsCV.pkl'
joblib.dump(reg, filename)
# Out:
# ['DRTPS_LarsCV.pkl']

# %%
from sklearn import linear_model

# Train the model
reg = linear_model.LassoLars(alpha=0.0001).fit(X_train, y_train)

# Evaluate the model using the test data
predictions = reg.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels ')
plt.title('Predicted Demand Transport by LassoLars model')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
reg.score(X_train, y_train)
# Out:
# MSE: 212.9663363307769
# RMSE: 14.5933661754503
# R2: 0.5398388554283303
# 0.6742695933093994

# %%
# Save the model as a pickle file
filename = 'DRTPS_LassoLars.pkl'
joblib.dump(reg, filename)
# Out:
# ['DRTPS_LassoLars.pkl']

# %%
from sklearn import linear_model

# Train the model
reg = linear_model.LassoLarsIC(criterion='bic',max_iter=100).fit(X_train, y_train)

# Evaluate the model using the test data
predictions = reg.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels ')
plt.title('Predicted Demand Transport by LassoLarsIC model')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
reg.score(X_train, y_train)
# Out:
# MSE: 339.7839032600051
# RMSE: 18.433228237614948
# R2: 0.2658212911720278
# 0.3514348746274213

# %%
# Save the model as a pickle file
filename = 'DRTPS_LassoLarsIC.pkl'
joblib.dump(reg, filename)
# Out:
# ['DRTPS_LassoLarsIC.pkl']

# %%
from sklearn.linear_model import ElasticNet
from sklearn.datasets import make_regression

# Train the model
X, y = make_regression(n_features=2, random_state=0)
regr = ElasticNet(random_state=0, l1_ratio = 0.1,).fit(X_train, y_train)

# Evaluate the model using the test data
predictions = regr.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels ')
plt.title('Predicted Demand Transport by ElasticNet model')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
reg.score(X_train, y_train)
# Out:
# MSE: 459.22792525494094
# RMSE: 21.42960394535888
# R2: 0.007735911010983587
# 0.3514348746274213

# %%
# Save the model as a pickle file
filename = 'DRTPS_ElasticNet.pkl'
joblib.dump(regr, filename)
# Out:
# ['DRTPS_ElasticNet.pkl']

# %%
from sklearn.linear_model import ElasticNetCV
from sklearn.datasets import make_regression

# Train the model
X, y = make_regression(n_features=2, random_state=0)
regr = ElasticNetCV(cv=5, random_state=0).fit(X_train, y_train)

# Evaluate the model using the test data
predictions = regr.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels ')
plt.title('Predicted Demand Transport by ElasticNetCV model')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
reg.score(X_train, y_train)
# Out:
# MSE: 212.89680301581828
# RMSE: 14.590983620572613
# R2: 0.5399890976231696
# 0.3514348746274213

# %%
# Save the model as a pickle file
filename = 'DRTPS_ElasticNetCV.pkl'
joblib.dump(regr, filename)
# Out:
# ['DRTPS_ElasticNetCV.pkl']

# %%
from sklearn.linear_model import OrthogonalMatchingPursuit
from sklearn.datasets import make_regression

# Train the model
X, y = make_regression(noise=4, random_state=0)
reg = OrthogonalMatchingPursuit().fit(X_train, y_train)

# Evaluate the model using the test data
predictions = reg.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels ')
plt.title('Predicted Demand Transport by OrthogonalMatchingPursuit model')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
reg.score(X_train, y_train)
# Out:
# MSE: 334.3674264024407
# RMSE: 18.28571645854875
# R2: 0.27752479433250654
# 0.3985133164583504

# %%
# Save the model as a pickle file
filename = 'DRTPS_OrthogonalMatchingPursuit.pkl'
joblib.dump(reg, filename)
# Out:
# ['DRTPS_OrthogonalMatchingPursuit.pkl']

# %%
from sklearn.linear_model import OrthogonalMatchingPursuitCV
from sklearn.datasets import make_regression

# Train the model
X, y = make_regression(n_features=1000, n_informative=10,noise=4, random_state=0)
reg = OrthogonalMatchingPursuitCV(cv=5).fit(X_train, y_train)

# Evaluate the model using the test data
predictions = reg.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels ')
plt.title('Predicted Demand Transport by OrthogonalMatchingPursuitCV model')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
reg.score(X_train, y_train)
# Out:
# MSE: 334.3674264024407
# RMSE: 18.28571645854875
# R2: 0.27752479433250654
# 0.3985133164583504

# %%
# Save the model as a pickle file
filename = 'DRTPS_OrthogonalMatchingPursuitCV.pkl'
joblib.dump(reg, filename)
# Out:
# ['DRTPS_OrthogonalMatchingPursuitCV.pkl']

# %%
from sklearn import linear_model

# Train the model
reg = linear_model.BayesianRidge().fit(X_train, y_train)

# Evaluate the model using the test data
predictions = reg.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels')
plt.title('Predicted Demand Transport by BayesianRidge')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
# Out:
# MSE: 212.81343177987273
# RMSE: 14.588126397172212
# R2: 0.5401692397245836

# %%
# Save the model as a pickle file
filename = 'DRTPS_BayesianRidge.pkl'
joblib.dump(reg, filename)
# Out:
# ['DRTPS_BayesianRidge.pkl']

# %%
from sklearn import linear_model

# Train the model
reg = linear_model.ARDRegression().fit(X_train, y_train)

# Evaluate the model using the test data
predictions = reg.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels')
plt.title('Predicted Demand Transport by ARDRegression model')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
# Out:
# MSE: 220.07393561847633
# RMSE: 14.834889134013652
# R2: 0.5244813060628539

# %%
# Save the model as a pickle file
filename = 'DRTPS_ARDRegression.pkl'
joblib.dump(reg, filename)
# Out:
# ['DRTPS_ARDRegression.pkl']

# %%
from sklearn import linear_model

# Train the model
reg = linear_model.TweedieRegressor().fit(X_train, y_train)

# Evaluate the model using the test data
predictions = reg.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels')
plt.title('Predicted Demand Transport by TweedieRegressor')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
# Out:
# MSE: 457.13223587405867
# RMSE: 21.38065096937085
# R2: 0.012264114110067004

# %%
# Save the model as a pickle file
filename = 'DRTPS_TweedieRegressor.pkl'
joblib.dump(reg, filename)
# Out:
# ['DRTPS_TweedieRegressor.pkl']

# %%
from sklearn.linear_model import PassiveAggressiveRegressor
from sklearn.datasets import make_regression

# Train the model
regr = PassiveAggressiveRegressor(max_iter=100,tol=1e-3).fit(X_train, y_train)

# Evaluate the model using the test data
predictions = regr.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels')
plt.title('Predicted Demand Transport by PassiveAggressiveRegressor')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
# Out:
# MSE: 867.9591466214123
# RMSE: 29.4611463901426
# R2: -0.8754188161006513

# %%
# Save the model as a pickle file
filename = 'DRTPS_PassiveAggressiveRegressor.pkl'
joblib.dump(regr, filename)
# Out:
# ['DRTPS_PassiveAggressiveRegressor.pkl']

# %%
from sklearn import linear_model

# Train the model
reg = linear_model.RANSACRegressor().fit(X_train, y_train)

# Evaluate the model using the test data
predictions = reg.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels')
plt.title('Predicted Demand Transport by RANSACRegressor')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
# Out:
# MSE: 2.5436641584526194e+25
# RMSE: 5043475149589.437
# R2: -5.496152259207249e+22

# %%
# Save the model as a pickle file
filename = 'DRTPS_RANSACRegressor.pkl'
joblib.dump(reg, filename)
# Out:
# ['DRTPS_RANSACRegressor.pkl']

# %%
from sklearn.linear_model import TheilSenRegressor
from sklearn.datasets import make_regression

# Train the model
X, y = make_regression(n_samples=200, n_features=2, noise=4.0,)
reg = TheilSenRegressor(random_state=0).fit(X_train, y_train)

# Evaluate the model using the test data
predictions = reg.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels')
plt.title('Predicted Demand Transport by TheilSenRegressor')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
# Out:
# MSE: 225.72582222741508
# RMSE: 15.02417459388086
# R2: 0.5122691477670045

# %%
# Save the model as a pickle file
filename = 'DRTPS_TheilSenRegressor.pkl'
joblib.dump(reg, filename)
# Out:
# ['DRTPS_TheilSenRegressor.pkl']

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split

# Train the model
X, y = make_regression(n_samples=2000)
reg = MLPRegressor(random_state=1, max_iter=3000).fit(X_train, y_train)

# Evaluate the model using the test data
predictions = reg.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels')
plt.title('Predicted Demand Transport by MLPRegressor')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
# Out:
# MSE: 278.8914192544496
# RMSE: 16.700042492594132
# R2: 0.3973930485613629

# %%
# Save the model as a pickle file
filename = 'DRTPS_MLPRegressor.pkl'
joblib.dump(reg, filename)
# Out:
# ['DRTPS_MLPRegressor.pkl']

# %%
from sklearn.datasets import make_friedman2
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import DotProduct, WhiteKernel

# Train the model
X, y = make_friedman2(n_samples=500, noise=0)
kernel = DotProduct() + WhiteKernel()
gpr = GaussianProcessRegressor(kernel=kernel, random_state=0).fit(X_train, y_train)

# Evaluate the model using the test data
predictions = gpr.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels')
plt.title('Predicted Demand Transport by GaussianProcessRegressor')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
# Out:
# MSE: 453.4734375600927
# RMSE: 21.29491576785625
# R2: 0.0201697617768255

# %%
# Save the model as a pickle file
filename = 'DRTPS_GaussianProcessRegressor.pkl'
joblib.dump(gpr, filename)
# Out:
# ['DRTPS_GaussianProcessRegressor.pkl']

# %%
from sklearn.kernel_ridge import KernelRidge
import numpy as np

# Train the model
rng = np.random.RandomState(0)
clf = KernelRidge(alpha=1.0)
clf.fit(X_train, y_train)

# Evaluate the model using the test data
predictions = clf.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels')
plt.title('Predicted Demand Transport by KernelRidge')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
# Out:
# MSE: 213.19488623534644
# RMSE: 14.601194685208004
# R2: 0.5393450225179726

# %%
# Save the model as a pickle file
filename = 'DRTPS_KernelRidge.pkl'
joblib.dump(clf, filename)
# Out:
# ['DRTPS_KernelRidge.pkl']

# %%
from sklearn.datasets import make_regression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split

# Train the model
X, y = make_regression(random_state=0)
reg = GradientBoostingRegressor(random_state=0)
reg.fit(X_train, y_train)
GradientBoostingRegressor(random_state=0)
reg.predict(X_test[1:2])

# Evaluate the model using the test data
predictions = reg.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels')
plt.title('Predicted Demand Transport by GradientBoostingRegressor')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
# Out:
# MSE: 270.36966479738163
# RMSE: 16.44292141918162
# R2: 0.41580619475284586

# %%
# Save the model as a pickle file
filename = 'DRTPS_GradientBoostingRegressor.pkl'
joblib.dump(reg, filename)
# Out:
# ['DRTPS_GradientBoostingRegressor.pkl']

# %%
from sklearn.dummy import DummyRegressor

# Train the model
dummy_regr = DummyRegressor(strategy="mean")
dummy_regr.fit(X_train, y_train)

# Evaluate the model using the test data
predictions = dummy_regr.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels')
plt.title('Predicted Demand Transport by DummyRegressor')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
# Out:
# MSE: 462.9246159826253
# RMSE: 21.51568302384624
# R2: -0.000251611644881633

# %%
# Save the model as a pickle file
filename = 'DRTPS_DummyRegressor.pkl'
joblib.dump(dummy_regr, filename)
# Out:
# ['DRTPS_DummyRegressor.pkl']

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.datasets import make_regression

# Train the model
regr = AdaBoostRegressor(n_estimators=1000)
regr.fit(X_train, y_train)
AdaBoostRegressor(n_estimators=100)

# Evaluate the model using the test data
predictions = regr.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels')
plt.title('Predicted Demand Transport by AdaBoostRegressor')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
# Out:
# MSE: 469.98312306232685
# RMSE: 21.67909414764203
# R2: -0.015503086374286212

# %%
# Save the model as a pickle file
filename = 'DRTPS_AdaBoostRegressor.pkl'
joblib.dump(regr, filename)
# Out:
# ['DRTPS_AdaBoostRegressor.pkl']

# %%
from sklearn.svm import SVR
from sklearn.ensemble import BaggingRegressor
from sklearn.datasets import make_regression

# Train the model
regr = BaggingRegressor(base_estimator=SVR(),
n_estimators=10, random_state=0).fit(X_train, y_train)

# Evaluate the model using the test data
predictions = regr.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels')
plt.title('Predicted Demand Transport by BaggingRegressor')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
# Out:
# MSE: 511.39289082614806
# RMSE: 22.61399767458527
# R2: -0.104978101341209

# %%
# Save the model as a pickle file
filename = 'DRTPS_BaggingRegressor.pkl'
joblib.dump(regr, filename)
# Out:
# ['DRTPS_BaggingRegressor.pkl']

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import ExtraTreesRegressor

# Train the model
reg = ExtraTreesRegressor(n_estimators=100, random_state=0).fit(X_train, y_train)
                     
# Evaluate the model using the test data
predictions = reg.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels')
plt.title('Predicted Demand Transport by ExtraTreesRegressor')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
# Out:
# MSE: 260.6730315457413
# RMSE: 16.14537183051977
# R2: 0.4367579279349211

# %%
# Save the model as a pickle file
filename = 'DRTPS_ExtraTreesRegressor.pkl'
joblib.dump(reg, filename)
# Out:
# ['DRTPS_ExtraTreesRegressor.pkl']

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
# Train the model
X, y = make_regression(n_features=4, n_informative=2, random_state=0, shuffle=False)
regr = RandomForestRegressor(max_depth=2, random_state=0)
regr.fit(X_train, y_train)
# Evaluate the model using the test data
predictions = regr.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels')
plt.title('Predicted Demand Transport by RandomForestRegressor')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
# Out:
# MSE: 388.21541291957436
# RMSE: 19.70318281191073
# R2: 0.1611742408341451

# %%
# Save the model as a pickle file
filename = 'DRTPS_RandomForestRegressor.pkl'
joblib.dump(regr, filename)
# Out:
# ['DRTPS_RandomForestRegressor.pkl']

# %%
from sklearn.experimental import enable_hist_gradient_boosting  # noqa
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.datasets import load_diabetes
# Train the model
est = HistGradientBoostingRegressor().fit(X_train, y_train)
# Evaluate the model using the test data
predictions = est.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels')
plt.title('Predicted Demand Transport by HistGradientBoostingRegressor')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
# Out:
# MSE: 457.92150345491154
# RMSE: 21.399100529108964
# R2: 0.010558725926957946

# %%
# Save the model as a pickle file
filename = 'DRTPS_HistGradientBoostingRegressor.pkl'
joblib.dump(est, filename)
# Out:
# ['DRTPS_HistGradientBoostingRegressor.pkl']

# %%
from sklearn.neighbors import KNeighborsRegressor
# Train the model
neigh = KNeighborsRegressor(n_neighbors=2)
neigh.fit(X, y).fit(X_train, y_train)
# Evaluate the model using the test data
predictions = neigh.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels')
plt.title('Predicted Demand Transport by KNeighborsRegressor')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
# Out:
# MSE: 699.2957413249211
# RMSE: 26.444200523459223
# R2: -0.5109840093336224

# %%
# Save the model as a pickle file
filename = 'DRTPS_KNeighborsRegressor.pkl'
joblib.dump(neigh, filename)
# Out:
# ['DRTPS_KNeighborsRegressor.pkl']

# %%
from sklearn.svm import LinearSVR
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_regression
# Train the model
X, y = make_regression(n_features=4, random_state=0)
regr = make_pipeline(StandardScaler(),LinearSVR(random_state=0, tol=1e-5))
regr.fit(X_train, y_train)
# Evaluate the model using the test data
predictions = regr.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels')
plt.title('Predicted Demand Transport by LinearSVR')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
# Out:
# MSE: 251.24600879930898
# RMSE: 15.850741585153326
# R2: 0.45712710764491904

# %%
# Save the model as a pickle file
filename = 'DRTPS_LinearSVR.pkl'
joblib.dump(regr, filename)
# Out:
# ['DRTPS_LinearSVR.pkl']

# %%
from sklearn.svm import NuSVR
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
# Train the model
regr = make_pipeline(StandardScaler(), NuSVR(C=1000.0, nu=0.1))
regr.fit(X_train, y_train)
# Evaluate the model using the test data
predictions = regr.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels')
plt.title('Predicted Demand Transport by NuSVR')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
# Out:
# MSE: 212.61493050118614
# RMSE: 14.581321287907558
# R2: 0.5405981458943243

# %%
# Save the model as a pickle file
filename = 'DRTPS_NuSVR.pkl'
joblib.dump(regr, filename)
# Out:
# ['DRTPS_NuSVR.pkl']

# %%
from sklearn.svm import SVR
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
# Train the model
n_samples, n_features = 10, 5
rng = np.random.RandomState(0)
y = rng.randn(n_samples)
X = rng.randn(n_samples, n_features)
regr = make_pipeline(StandardScaler(), SVR(C=1.0, epsilon=0.2))
regr.fit(X_train, y_train)
# Evaluate the model using the test data
predictions = regr.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels')
plt.title('Predicted Demand Transport by SVR')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
# Out:
# MSE: 416.67158092180455
# RMSE: 20.41253489701376
# R2: 0.09968835971492518

# %%
# Save the model as a pickle file
filename = 'DRTPS_SVR.pkl'
joblib.dump(regr, filename)
# Out:
# ['DRTPS_SVR.pkl']
