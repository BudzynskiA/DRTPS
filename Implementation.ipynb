# %%
#Import needed library
import pandas as pd
import joblib

# %%
df = pd.read_csv('20210820222023.csv',delimiter=',',header='infer')

# %%
# Create new features

# Classification country load place:
df['LC_AD'] = df['LC'] == 'AD'
df['LC_AL'] = df['LC'] == 'AL'
df['LC_AM'] = df['LC'] == 'AM'
df['LC_AT'] = df['LC'] == 'AT'
df['LC_AZ'] = df['LC'] == 'AZ'
df['LC_BA'] = df['LC'] == 'BA'
df['LC_BE'] = df['LC'] == 'BE'
df['LC_BG'] = df['LC'] == 'BG'
df['LC_BY'] = df['LC'] == 'BY'
df['LC_CH'] = df['LC'] == 'CH'
df['LC_CY'] = df['LC'] == 'CY'
df['LC_CZ'] = df['LC'] == 'CZ'
df['LC_DE'] = df['LC'] == 'DE'
df['LC_DK'] = df['LC'] == 'DK'
df['LC_EE'] = df['LC'] == 'EE'
df['LC_ES'] = df['LC'] == 'ES'
df['LC_FI'] = df['LC'] == 'FI'
df['LC_FR'] = df['LC'] == 'FR'
df['LC_GB'] = df['LC'] == 'GB'
df['LC_GE'] = df['LC'] == 'GE'
df['LC_GR'] = df['LC'] == 'GR'
df['LC_HR'] = df['LC'] == 'HR'
df['LC_HU'] = df['LC'] == 'HU'
df['LC_IE'] = df['LC'] == 'IE'
df['LC_IS'] = df['LC'] == 'IS'
df['LC_IT'] = df['LC'] == 'IT'
df['LC_KZ'] = df['LC'] == 'KZ'
df['LC_LT'] = df['LC'] == 'LT'
df['LC_LU'] = df['LC'] == 'LU'
df['LC_LV'] = df['LC'] == 'LV'
df['LC_MD'] = df['LC'] == 'MD'
df['LC_ME'] = df['LC'] == 'ME'
df['LC_MK'] = df['LC'] == 'MK'
df['LC_NL'] = df['LC'] == 'NL'
df['LC_NO'] = df['LC'] == 'NO'
df['LC_PL'] = df['LC'] == 'PL'
df['LC_PT'] = df['LC'] == 'PT'
df['LC_RO'] = df['LC'] == 'RO'
df['LC_RS'] = df['LC'] == 'RS'
df['LC_RU'] = df['LC'] == 'RU'
df['LC_SE'] = df['LC'] == 'SE'
df['LC_SI'] = df['LC'] == 'SI'
df['LC_SK'] = df['LC'] == 'SK'
df['LC_TR'] = df['LC'] == 'TR'
df['LC_UA'] = df['LC'] == 'UA'

# Classification country delivery place:
df['DC_AD'] = df['DC'] == 'AD'
df['DC_AL'] = df['DC'] == 'AL'
df['DC_AM'] = df['DC'] == 'AM'
df['DC_AT'] = df['DC'] == 'AT'
df['DC_AZ'] = df['DC'] == 'AZ'
df['DC_BA'] = df['DC'] == 'BA'
df['DC_BE'] = df['DC'] == 'BE'
df['DC_BG'] = df['DC'] == 'BG'
df['DC_BY'] = df['DC'] == 'BY'
df['DC_CH'] = df['DC'] == 'CH'
df['DC_CY'] = df['DC'] == 'CY'
df['DC_CZ'] = df['DC'] == 'CZ'
df['DC_DE'] = df['DC'] == 'DE'
df['DC_DK'] = df['DC'] == 'DK'
df['DC_EE'] = df['DC'] == 'EE'
df['DC_ES'] = df['DC'] == 'ES'
df['DC_FI'] = df['DC'] == 'FI'
df['DC_FR'] = df['DC'] == 'FR'
df['DC_GB'] = df['DC'] == 'GB'
df['DC_GE'] = df['DC'] == 'GE'
df['DC_GR'] = df['DC'] == 'GR'
df['DC_HR'] = df['DC'] == 'HR'
df['DC_HU'] = df['DC'] == 'HU'
df['DC_IE'] = df['DC'] == 'IE'
df['DC_IS'] = df['DC'] == 'IS'
df['DC_IT'] = df['DC'] == 'IT'
df['DC_KZ'] = df['DC'] == 'KZ'
df['DC_LT'] = df['DC'] == 'LT'
df['DC_LU'] = df['DC'] == 'LU'
df['DC_LV'] = df['DC'] == 'LV'
df['DC_MD'] = df['DC'] == 'MD'
df['DC_ME'] = df['DC'] == 'ME'
df['DC_MK'] = df['DC'] == 'MK'
df['DC_NL'] = df['DC'] == 'NL'
df['DC_NO'] = df['DC'] == 'NO'
df['DC_PL'] = df['DC'] == 'PL'
df['DC_PT'] = df['DC'] == 'PT'
df['DC_RO'] = df['DC'] == 'RO'
df['DC_RS'] = df['DC'] == 'RS'
df['DC_RU'] = df['DC'] == 'RU'
df['DC_SE'] = df['DC'] == 'SE'
df['DC_SI'] = df['DC'] == 'SI'
df['DC_SK'] = df['DC'] == 'SK'
df['DC_TR'] = df['DC'] == 'TR'
df['DC_UA'] = df['DC'] == 'UA'

#Data as year and month together
df['YM'] = df['Y']+(df['M']/12)-(1/12)

#Month Classification
df['January'] = df['M'] == 1
df['February'] = df['M'] == 2
df['March'] = df['M'] == 3
df['April'] = df['M'] == 4
df['May'] = df['M'] == 5
df['June'] = df['M'] == 6
df['July'] = df['M'] == 7
df['August'] = df['M'] == 8
df['September'] = df['M'] == 9
df['October'] = df['M'] == 10
df['Novemer'] = df['M'] == 11
df['December'] = df['M'] == 12

#Year Classification
df['2019'] = df['Y'] == 2019
df['2020'] = df['Y'] == 2020
df['2021'] = df['Y'] == 2021
df['2022'] = df['Y'] == 2022
df['2023'] = df['Y'] == 2023

# %%
#Change false into 0 and true into 1
df = df*1

# %%
X_new = df[[  'LC_AD',
 'LC_AL',
 'LC_AM',
 'LC_AT',
 'LC_AZ',
 'LC_BA',
 'LC_BE',
 'LC_BG',
 'LC_BY',
 'LC_CH',
 'LC_CY',
 'LC_CZ',
 'LC_DE',
 'LC_DK',
 'LC_EE',
 'LC_ES',
 'LC_FI',
 'LC_FR',
 'LC_GB',
 'LC_GE',
 'LC_GR',
 'LC_HR',
 'LC_HU',
 'LC_IE',
 'LC_IS',
 'LC_IT',
 'LC_KZ',
 'LC_LT',
 'LC_LU',
 'LC_LV',
 'LC_MD',
 'LC_ME',
 'LC_MK',
 'LC_NL',
 'LC_NO',
 'LC_PL',
 'LC_PT',
 'LC_RO',
 'LC_RS',
 'LC_RU',
 'LC_SE',
 'LC_SI',
 'LC_SK',
 'LC_TR',
 'LC_UA',
 'DC_AD',
 'DC_AL',
 'DC_AM',
 'DC_AT',
 'DC_AZ',
 'DC_BA',
 'DC_BE',
 'DC_BG',
 'DC_BY',
 'DC_CH',
 'DC_CY',
 'DC_CZ',
 'DC_DE',
 'DC_DK',
 'DC_EE',
 'DC_ES',
 'DC_FI',
 'DC_FR',
 'DC_GB',
 'DC_GE',
 'DC_GR',
 'DC_HR',
 'DC_HU',
 'DC_IE',
 'DC_IS',
 'DC_IT',
 'DC_KZ',
 'DC_LT',
 'DC_LU',
 'DC_LV',
 'DC_MD',
 'DC_ME',
 'DC_MK',
 'DC_NL',
 'DC_NO',
 'DC_PL',
 'DC_PT',
 'DC_RO',
 'DC_RS',
 'DC_RU',
 'DC_SE',
 'DC_SI',
 'DC_SK',
 'DC_TR',
 'DC_UA',
 'January',
 'February',
 'March',
 'April',
 'May',
 'June',
 'July',
 'August',
 'September',
 'October',
 'Novemer',
 'December',
'2019','2020','2021','2022','2023',
    'YM'
]].values

# %%
model = joblib.load('DRTPS_TheilSenRegressor2.pkl')
df['D'] = model.predict(X_new)

# %%
df.to_csv('IMPLEMENTATION.csv')

# %%
df.to_excel('IMPLEMENTATION.xlsx')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-8-47c024207294> in <module>
# ----> 1 df.to_excel('IMPLEMENTATION.xlsx')
#
# C:\Anaconda 15.06.2021\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2187             inf_rep=inf_rep,
#    2188         )
# -> 2189         formatter.write(
#    2190             excel_writer,
#    2191             sheet_name=sheet_name,
#
# C:\Anaconda 15.06.2021\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     813             # abstract class 'ExcelWriter' with abstract attributes 'engine',
# ...
